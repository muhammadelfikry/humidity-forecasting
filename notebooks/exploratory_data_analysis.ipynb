# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("../data/processed/dataset.xlsx")
df
# Out:
#          Tanggal    Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  ff_avg  \
# 0     01-01-2010  24.0  32.4  25.9    85.0   0.0  1.5   NaN    NaN     NaN
# 1     02-01-2010  24.0  31.6  27.6    83.0   5.0  0.5   NaN    NaN     NaN
# 2     03-01-2010  24.0  29.6  27.0    86.0  24.0  3.2   NaN    NaN     NaN
# 3     04-01-2010  24.0  32.0  27.4    84.0   0.0  4.1   NaN    NaN     NaN
# 4     05-01-2010  24.0  34.4  27.8    80.0   8.0  4.2   NaN    NaN     NaN
# ...          ...   ...   ...   ...     ...   ...  ...   ...    ...     ...
# 5139  25-02-2024  24.6  33.4  30.3    72.0   0.0  7.8   5.0   60.0     1.0
# 5140  26-02-2024  24.0  33.2  29.8    73.0   NaN  2.6   6.0  100.0     2.0
# 5141  27-02-2024  23.8  35.0  31.3    63.0   NaN  3.6   5.0   30.0     2.0
# 5142  28-02-2024  24.6  35.3  31.4    63.0   NaN  5.4   7.0   70.0     2.0
# 5143  29-02-2024  24.6  32.2  29.3    79.0   NaN  6.3   5.0   30.0     1.0
#
#      ddd_car
# 0        NaN
# 1        NaN
# 2        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5144 entries, 0 to 5143
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Tanggal  5144 non-null   object
#  1   Tn       4939 non-null   float64
#  2   Tx       4985 non-null   float64
#  3   Tavg     5136 non-null   float64
#  4   RH_avg   5136 non-null   float64
#  5   RR       3841 non-null   float64
#  6   ss       5009 non-null   float64
#  7   ff_x     4384 non-null   float64
#  8   ddd_x    4369 non-null   float64
#  9   ff_avg   4591 non-null   float64
#  10  ddd_car  4591 non-null   object
# dtypes: float64(9), object(2)
# memory usage: 442.2+ KB

# %%
df.describe()
# Out:
#                 Tn           Tx         Tavg       RH_avg           RR  \
# count  4939.000000  4985.000000  5136.000000  5136.000000  3841.000000
# mean     25.614598    32.924293    28.199299    78.990849    10.940406
# std     141.945608     1.679400     1.401539     6.025790    18.362031
# min      14.000000    23.400000    20.600000     7.000000     0.000000
# 25%      23.000000    32.000000    27.200000    75.000000     0.000000
# 50%      23.800000    33.000000    28.200000    79.000000     2.500000
# 75%      24.200000    34.000000    29.000000    83.000000    13.700000
# max    9999.000000    39.600000    33.200000    97.000000   160.100000
#
#                 ss         ff_x        ddd_x       ff_avg
# count  5009.000000  4384.000000  4369.000000  4591.000000
# mean      5.420303     4.138914   166.487755     1.358092
# std     141.254637     2.556788   111.935760     0.892391
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Tanggal       0
# Tn          205
# Tx          159
# Tavg          8
# RH_avg        8
# RR         1303
# ss          135
# ff_x        760
# ddd_x       775
# ff_avg      553
# ddd_car     553
# dtype: int64

# %%
df.shape
# Out:
# (5144, 11)

# %%
sns.boxplot(x=df["RH_avg"])
# Out:
# <Axes: xlabel='RH_avg'>

# %%
plt.figure(figsize=(15, 5))
plt.plot(df["RH_avg"])
plt.title("Humidity Average",
          fontsize=20)
# Out:
# Text(0.5, 1.0, 'Humidity Average')
